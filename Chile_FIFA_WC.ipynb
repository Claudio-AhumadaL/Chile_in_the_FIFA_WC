# %%
import pandas as pd

# %%
# Load team_appareances database and obtain a dataframe with Chile's matches

team_appearances = pd.read_csv('./data-csv/team_appearances.csv')
tappearances_mask = team_appearances['match_name'].str.contains('Chile')
team_appearances_chile = team_appearances[tappearances_mask]

team_appearances_chile.head()

# Export CSV file

team_appearances_chile.to_csv('./chile-data-csv/team_appearances_chile.csv', index=False)
# Out:
# 'key_id,tournament_id,tournament_name,match_id,match_name,stage_name,group_name,group_stage,knockout_stage,replayed,replay,match_date,match_time,stadium_id,stadium_name,city_name,country_name,team_id,team_name,team_code,opponent_id,opponent_name,opponent_code,home_team,away_team,goals_for,goals_against,goal_differential,extra_time,penalty_shootout,penalties_for,penalties_against,result,win,lose,draw\r\n11,WC-1930,1930 FIFA World Cup,M-1930-06,Chile v Mexico,group stage,Group 1,1,0,0,0,1930-07-16,14:45,S-192,Estadio Gran Parque Central,Montevideo,Uruguay,T-13,Chile,CHL,T-44,Mexico,MEX,1,0,3,0,3,0,0,0,0,win,1,0,0\r\n12,WC-1930,1930 FIFA World Cup,M-1930-06,Chile v Mexico,group stage,Group 1,1,0,0,0,1930-07-16,14:45,S-192,Estadio Gran Parque Central,Montevideo,Uruguay,T-44,Mexico,MEX,T-13,Chile,CHL,0,1,0,3,-3,0,0,0,0,lose,0,1,0\r\n19,WC-1930,1930 FIFA World Cup,M-1930-10,Chile v France,group stage,Group 1,1,0,0,0,1930-07-19,12:50,S-191,Estadio Centenario,Montevideo,Uruguay,T-13,Chile,CH
# ...

# %%
# Load bookings database and restrict to only have values for Chile

bookings = pd.read_csv('./data-csv/bookings.csv')
bookings_chile = bookings[bookings['team_name'] == 'Chile']
bookings_chile

# Export CSV file

bookings_chile.to_csv('./chile-data-csv/bookings_chile.csv', index=False)
# Out:
# 'key_id,booking_id,tournament_id,tournament_name,match_id,match_name,match_date,stage_name,group_name,team_id,team_name,team_code,home_team,away_team,player_id,family_name,given_name,shirt_number,minute_label,minute_regulation,minute_stoppage,match_period,yellow_card,red_card,second_yellow_card,sending_off\r\n55,B-0055,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-07348,Caszely,Carlos,7,13\',13,0,first half,1,0,0,0\r\n56,B-0056,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-05748,Reinoso,Carlos,10,47\',47,0,second half,1,0,0,0\r\n57,B-0057,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-01623,García,Rolando,2,59\',59,0,second half,1,0,0,0\r\n58,B-0058,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-07348,Caszely,Carlos,7,67\',67,0,se
# ...

# %%
# Load goals database and obtain two different dataframes, one for goals Scored by Chile and another for goals scored to Chile

goals = pd.read_csv('./data-csv/goals.csv')
goals_by_chile = goals[goals['team_name'] == 'Chile']

mask = goals['match_name'].str.contains('Chile') & ~goals['team_name'].str.contains('Chile')
goals_to_chile = goals[mask]

# Export CSV file

goals_by_chile.to_csv('./chile-data-csv/goals_by_chile.csv', index=False)
goals_to_chile.to_csv('./chile-data-csv/goals_to_chile.csv', index=False)
# Out:
# 'key_id,goal_id,tournament_id,tournament_name,match_id,match_name,match_date,stage_name,group_name,team_id,team_name,team_code,home_team,away_team,player_id,family_name,given_name,shirt_number,player_team_id,player_team_name,player_team_code,minute_label,minute_regulation,minute_stoppage,match_period,own_goal,penalty\r\n47,G-0047,WC-1930,1930 FIFA World Cup,M-1930-15,Argentina v Chile,1930-07-22,group stage,Group 1,T-03,Argentina,ARG,1,0,P-01708,Stábile,Guillermo,0,T-03,Argentina,ARG,12\',12,0,first half,0,0\r\n48,G-0048,WC-1930,1930 FIFA World Cup,M-1930-15,Argentina v Chile,1930-07-22,group stage,Group 1,T-03,Argentina,ARG,1,0,P-01708,Stábile,Guillermo,0,T-03,Argentina,ARG,13\',13,0,first half,0,0\r\n50,G-0050,WC-1930,1930 FIFA World Cup,M-1930-15,Argentina v Chile,1930-07-22,group stage,Group 1,T-03,Argentina,ARG,1,0,P-03577,Evaristo,Mario,0,T-03,Argentina,ARG,51\',51,0,second half,0,0\r\n232,G-0232,WC-1950,1950 FIFA World Cup,M-1950-03,England v Chile,1950-06-25,group stage,Group
# ...

# %%
# Load group_standings database and obtain a dataframe for Chile's results

group_standings = pd.read_csv('./data-csv/group_standings.csv')

group_standings_chile = group_standings[group_standings['team_name'] == 'Chile']
group_standings_chile.head()

# Export CSV file

group_standings_chile.to_csv('./chile-data-csv/group_standings_chile.csv', index=False)
# Out:
# 'key_id,tournament_id,tournament_name,stage_number,stage_name,group_name,position,team_id,team_name,team_code,played,wins,draws,losses,goals_for,goals_against,goal_difference,points,advanced\r\n2,WC-1930,1930 FIFA World Cup,1,group stage,Group 1,2,T-13,Chile,CHL,3,2,0,1,5,3,2,4,0\r\n20,WC-1950,1950 FIFA World Cup,1,first round,Group 2,3,T-13,Chile,CHL,3,1,0,2,5,6,-1,2,0\r\n68,WC-1962,1962 FIFA World Cup,1,group stage,Group 2,2,T-13,Chile,CHL,3,2,0,1,5,3,2,4,1\r\n94,WC-1966,1966 FIFA World Cup,1,group stage,Group 4,4,T-13,Chile,CHL,3,0,1,2,2,5,-3,1,0\r\n113,WC-1974,1974 FIFA World Cup,1,first group stage,Group 1,3,T-13,Chile,CHL,3,0,2,1,1,2,-1,2,0\r\n166,WC-1982,1982 FIFA World Cup,1,first group stage,Group 2,4,T-13,Chile,CHL,3,0,0,3,3,8,-5,0,0\r\n272,WC-1998,1998 FIFA World Cup,1,group stage,Group B,2,T-13,Chile,CHL,3,0,3,0,4,4,0,3,1\r\n392,WC-2010,2010 FIFA World Cup,1,group stage,Group H,2,T-13,Chile,CHL,3,2,0,1,3,2,1,6,1\r\n400,WC-2014,2014 FIFA World Cup,1,group stage,Group B,2,T
# ...

# %%
# Load manager_appearances database and obtain a dataframe for Chile's managers

manager_appearances = pd.read_csv('./data-csv/manager_appearances.csv')

manager_appearances_chile = manager_appearances[manager_appearances['team_name'] == 'Chile']
manager_appearances_chile.head()

# Export CSV file

manager_appearances_chile.to_csv('./chile-data-csv/manager_appearances_chile.csv', index=False)
# Out:
# 'key_id,tournament_id,tournament_name,match_id,match_name,match_date,stage_name,group_name,team_id,team_name,team_code,home_team,away_team,manager_id,family_name,given_name,country_name\r\n12,WC-1930,1930 FIFA World Cup,M-1930-06,Chile v Mexico,1930-07-16,group stage,Group 1,T-13,Chile,CHL,1,0,M-240,Orth,György,Hungary\r\n20,WC-1930,1930 FIFA World Cup,M-1930-10,Chile v France,1930-07-19,group stage,Group 1,T-13,Chile,CHL,1,0,M-240,Orth,György,Hungary\r\n33,WC-1930,1930 FIFA World Cup,M-1930-15,Argentina v Chile,1930-07-22,group stage,Group 1,T-13,Chile,CHL,0,1,M-240,Orth,György,Hungary\r\n124,WC-1950,1950 FIFA World Cup,M-1950-03,England v Chile,1950-06-25,group stage,Group 2,T-13,Chile,CHL,0,1,M-048,Buccicardi,Alberto,Chile\r\n134,WC-1950,1950 FIFA World Cup,M-1950-08,Spain v Chile,1950-06-29,group stage,Group 2,T-13,Chile,CHL,0,1,M-048,Buccicardi,Alberto,Chile\r\n141,WC-1950,1950 FIFA World Cup,M-1950-12,Chile v United States,1950-07-02,group stage,Group 2,T-13,Chile,CHL,1,0,M-048
# ...

# %%
# Load matches database and obtain a dataframe for Chile's matches

matches = pd.read_csv('./data-csv/matches.csv')

matches_mask = matches['match_name'].str.contains('Chile')
matches_chile = matches[matches_mask]

matches_chile.head()

# Export CSV file

matches_chile.to_csv('./chile-data-csv/team_appearances_chile.csv', index=False)
# Out:
# 'key_id,tournament_id,tournament_name,match_id,match_name,stage_name,group_name,group_stage,knockout_stage,replayed,replay,match_date,match_time,stadium_id,stadium_name,city_name,country_name,home_team_id,home_team_name,home_team_code,away_team_id,away_team_name,away_team_code,score,home_team_score,away_team_score,home_team_score_margin,away_team_score_margin,extra_time,penalty_shootout,score_penalties,home_team_score_penalties,away_team_score_penalties,result,home_team_win,away_team_win,draw\r\n6,WC-1930,1930 FIFA World Cup,M-1930-06,Chile v Mexico,group stage,Group 1,1,0,0,0,1930-07-16,14:45,S-192,Estadio Gran Parque Central,Montevideo,Uruguay,T-13,Chile,CHL,T-44,Mexico,MEX,3–0,3,0,3,-3,0,0,0-0,0,0,home team win,1,0,0\r\n10,WC-1930,1930 FIFA World Cup,M-1930-10,Chile v France,group stage,Group 1,1,0,0,0,1930-07-19,12:50,S-191,Estadio Centenario,Montevideo,Uruguay,T-13,Chile,CHL,T-28,France,FRA,1–0,1,0,1,-1,0,0,0-0,0,0,home team win,1,0,0\r\n15,WC-1930,1930 FIFA World Cup,M-1930-15,
# ...

# %%
# Load player_appearances database and obtain a dataframe for Chile's players

player_appearances = pd.read_csv('./data-csv/player_appearances.csv')

player_appearances_chile = player_appearances[player_appearances['team_name'] == 'Chile']

player_appearances_chile.head()

# Export CSV file

player_appearances_chile.to_csv(index=False)
# Out:
# 'key_id,tournament_id,tournament_name,match_id,match_name,match_date,stage_name,group_name,team_id,team_name,team_code,home_team,away_team,player_id,family_name,given_name,shirt_number,position_name,position_code,starter,substitute,captain\r\n843,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-01974,Vallejos,Leopoldo,1,goal keeper,GK,1,0,0\r\n844,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-01623,García,Rolando,2,right back,RB,1,0,0\r\n845,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-03988,Quintano,Alberto,3,center back,CB,1,0,0\r\n846,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,CHL,0,1,P-06201,Arias,Antonio,4,left back,LB,1,0,0\r\n847,WC-1974,1974 FIFA World Cup,M-1974-02,West Germany v Chile,1974-06-14,group stage,Group 1,T-13,Chile,C
# ...

# %%
# Load qualified_teams database and obtain a dataframe for Chile's results

qualified_teams = pd.read_csv("./data-csv/qualified_teams.csv")

qualified_teams_chile = qualified_teams[qualified_teams['team_name'] == 'Chile']
qualified_teams_chile.head(10)

# Export CSV file

qualified_teams_chile.to_csv(index=False)
# Out:
# 'key_id,tournament_id,tournament_name,team_id,team_name,team_code,count_matches,performance\r\n5,WC-1930,1930 FIFA World Cup,T-13,Chile,CHL,3,group stage\r\n47,WC-1950,1950 FIFA World Cup,T-13,Chile,CHL,3,group stage\r\n93,WC-1962,1962 FIFA World Cup,T-13,Chile,CHL,6,third-place match\r\n109,WC-1966,1966 FIFA World Cup,T-13,Chile,CHL,3,group stage\r\n142,WC-1974,1974 FIFA World Cup,T-13,Chile,CHL,3,group stage\r\n176,WC-1982,1982 FIFA World Cup,T-13,Chile,CHL,3,group stage\r\n272,WC-1998,1998 FIFA World Cup,T-13,Chile,CHL,4,round of 16\r\n367,WC-2010,2010 FIFA World Cup,T-13,Chile,CHL,4,round of 16\r\n401,WC-2014,2014 FIFA World Cup,T-13,Chile,CHL,4,round of 16\r\n'
